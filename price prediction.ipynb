# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Training_Data_Set.csv')
df
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad        NaN          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   53515 non-null  int64
#  1   Maker                53515 non-null  object
#  2   model                53515 non-null  object
#  3   Location             53515 non-null  object
#  4   Distance             52304 non-null  float64
#  5   Owner Type           53515 non-null  object
#  6   manufacture_year     53515 non-null  int64
#  7   Age of car           53515 non-null  int64
#  8   engine_displacement  53515 non-null  int64
#  9   engine_power         52076 non-null  float64
#  10  body_type            4136 non-null   object
#  11  Vroom Audit Rating   53515 non-null  int64
#  12  transmission         53515 non-null  object
#  13  door_count           45981 non-null  float64
#  14  seat_count           45004 non-null  float64
# ...

# %%
df.boxplot(fontsize=6)
plt.show()

# %%
df.shape
# Out:
# (53515, 17)

# %%
df.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count              7534
# seat_count              8511
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
df.drop(columns='body_type',inplace=True)

# %%
df
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad        NaN          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   53515 non-null  int64
#  1   Maker                53515 non-null  object
#  2   model                53515 non-null  object
#  3   Location             53515 non-null  object
#  4   Distance             52304 non-null  float64
#  5   Owner Type           53515 non-null  object
#  6   manufacture_year     53515 non-null  int64
#  7   Age of car           53515 non-null  int64
#  8   engine_displacement  53515 non-null  int64
#  9   engine_power         52076 non-null  float64
#  10  Vroom Audit Rating   53515 non-null  int64
#  11  transmission         53515 non-null  object
#  12  door_count           45981 non-null  float64
#  13  seat_count           45004 non-null  float64
#  14  fuel_type            53515 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance               1211
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power           1439
# Vroom Audit Rating        0
# transmission              0
# door_count             7534
# seat_count             8511
# fuel_type                 0
# Price                     0
# dtype: int64

# %%
df['seat_count'].sample(10)
# Out:
# 25951    5.0
# 41071    5.0
# 14150    5.0
# 3742     5.0
# 6047     5.0
# 51155    5.0
# 36401    5.0
# 27252    2.0
# 28588    NaN
# 37504    NaN
# Name: seat_count, dtype: float64

# %%
df['seat_count'].fillna(df['seat_count'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1285228065.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['seat_count'].fillna(df['seat_count'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance               1211
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power           1439
# Vroom Audit Rating        0
# transmission              0
# door_count             7534
# seat_count                0
# fuel_type                 0
# Price                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
df['door_count'].fillna(df['door_count'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\269680246.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['door_count'].fillna(df['door_count'].mode()[0],inplace=True)

# %%
df['Distance '].fillna(df['Distance '].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\2970458654.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Distance '].fillna(df['Distance '].median(),inplace=True)

# %%
df['engine_power'].fillna(df['engine_power'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\3278638123.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['engine_power'].fillna(df['engine_power'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   53515 non-null  int64
#  1   Maker                53515 non-null  object
#  2   model                53515 non-null  object
#  3   Location             53515 non-null  object
#  4   Distance             53515 non-null  float64
#  5   Owner Type           53515 non-null  object
#  6   manufacture_year     53515 non-null  int64
#  7   Age of car           53515 non-null  int64
#  8   engine_displacement  53515 non-null  int64
#  9   engine_power         53515 non-null  float64
#  10  Vroom Audit Rating   53515 non-null  int64
#  11  transmission         53515 non-null  object
#  12  door_count           53515 non-null  float64
#  13  seat_count           53515 non-null  float64
#  14  fuel_type            53515 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.boxplot()
plt.show()

# %%
df_cat=df.select_dtypes(include=object)
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Maker         53515 non-null  object
#  1   model         53515 non-null  object
#  2   Location      53515 non-null  object
#  3   Owner Type    53515 non-null  object
#  4   transmission  53515 non-null  object
#  5   fuel_type     53515 non-null  object
# dtypes: object(6)
# memory usage: 2.4+ MB

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_cat.dtypes
# Out:
# Maker           object
# model           object
# Location        object
# Owner Type      object
# transmission    object
# fuel_type       object
# dtype: object

# %%
df_num=df.select_dtypes(exclude=object).astype('int')
df_num.dtypes
# Out:
# Id                     int64
# Distance               int64
# manufacture_year       int64
# Age of car             int64
# engine_displacement    int64
# engine_power           int64
# Vroom Audit Rating     int64
# door_count             int64
# seat_count             int64
# Price                  int64
# dtype: object

# %%
df_cat['Maker']=le.fit_transform(df_cat['Maker'])

# %%
df_cat.dtypes
# Out:
# Maker            int64
# model           object
# Location        object
# Owner Type      object
# transmission    object
# fuel_type       object
# dtype: object

# %%
df_cat['model']=le.fit_transform(df_cat['model'])

# %%
df_cat['Location']=le.fit_transform(df_cat['Location'])

# %%
df_cat['Owner Type']=le.fit_transform(df_cat['Owner Type'])

# %%
df_cat['transmission']=le.fit_transform(df_cat['transmission'])

# %%
df_cat['fuel_type']=le.fit_transform(df_cat['fuel_type'])

# %%
df_cat.dtypes
# Out:
# Maker           int64
# model           int64
# Location        int64
# Owner Type      int64
# transmission    int64
# fuel_type       int64
# dtype: object

# %%
df_cat=pd.concat([df_cat,df_num],axis=1)

# %%
df_cat[['Price']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   53515 non-null  int64
# dtypes: int64(1)
# memory usage: 418.2 KB

# %%
df_cat
# Out:
#        Maker  model  Location  Owner Type  transmission  fuel_type     Id  \
# 0          6      8         0           2             1          1  25001
# 1          2      9         0           3             1          1  25002
# 2          1     18         5           3             0          0  25003
# 3          5      6         9           3             1          1  25004
# 4          1     20         6           1             0          0  25005
# ...      ...    ...       ...         ...           ...        ...    ...
# 53510      6      8         4           1             1          0  78511
# 53511      6      8         1           1             1          0  78512
# 53512      1     18        10           3             0          0  78513
# 53513      7      1         6           3             1          0  78514
# 53514      1     20         7           0             0          0  78515
#
#        Distance   manufacture_year  Age of car  engine_displacement  \
# ...

# %%
df_cat.dtypes
# Out:
# Maker                  int64
# model                  int64
# Location               int64
# Owner Type             int64
# transmission           int64
# fuel_type              int64
# Id                     int64
# Distance               int64
# manufacture_year       int64
# Age of car             int64
# engine_displacement    int64
# engine_power           int64
# Vroom Audit Rating     int64
# door_count             int64
# seat_count             int64
# Price                  int64
# dtype: object

# %%
df_cat.boxplot(figsize=(15,10))
plt.show()

# %%
df_cat.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
#        'Id', 'Distance ', 'manufacture_year', 'Age of car',
#        'engine_displacement', 'engine_power', 'Vroom Audit Rating',
#        'door_count', 'seat_count', 'Price'],
#       dtype='object')

# %%
df_outliers=df_cat[['Distance ','manufacture_year','Age of car','engine_displacement','engine_power','door_count','seat_count']]

# %%
df_outliers
# Out:
#        Distance   manufacture_year  Age of car  engine_displacement  \
# 0          65520              1964          55                 1964
# 1          27750              2012           7                 1242
# 2          46000              2014           5                 1995
# 3          43949              2011           8                 1618
# 4          59524              2012           7                 2993
# ...          ...               ...         ...                  ...
# 53510      29334              2014           5                 1598
# 53511     223631              2009          10                 1900
# 53512      25500              2015           4                 1995
# 53513    1195500              2011           8                11950
# 53514     142000              2008          11                 2993
#
#        engine_power  door_count  seat_count
# 0               147           4           5
# 1                51           4           4
# ...

# %%
z=(df_outliers-df_outliers.mean())/df_outliers.std()
z
# Out:
#        Distance   manufacture_year  Age of car  engine_displacement  \
# 0      -0.104123         -9.979547    9.979547             0.040059
# 1      -0.242749          0.342318   -0.342318            -0.442379
# 2      -0.175767          0.772396   -0.772396             0.060773
# 3      -0.183294          0.127279   -0.127279            -0.191137
# 4      -0.126130          0.342318   -0.342318             0.727634
# ...          ...               ...         ...                  ...
# 53510  -0.236935          0.772396   -0.772396            -0.204501
# 53511   0.476186         -0.302798    0.302798            -0.002706
# 53512  -0.251007          0.987435   -0.987435             0.060773
# 53513   4.043199          0.127279   -0.127279             6.712674
# 53514   0.176578         -0.517837    0.517837             0.727634
#
#        engine_power  door_count  seat_count
# 0          1.051353    0.033774    0.184493
# 1         -1.087800    0.033774   -1.741594
# ...

# %%
z=z[(z>-2)&(z<2)]

# %%
z.boxplot()
plt.show()

# %%
z.isna().sum()
# Out:
# Distance                158
# manufacture_year       2803
# Age of car             2803
# engine_displacement     498
# engine_power           2512
# door_count             4358
# seat_count             1713
# dtype: int64

# %%
z['Distance '].fillna(z['Distance '].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1885902995.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z['Distance '].fillna(z['Distance '].median(),inplace=True)

# %%
z['manufacture_year'].fillna(z['manufacture_year'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\2956530448.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z['manufacture_year'].fillna(z['manufacture_year'].median(),inplace=True)

# %%
z['Age of car'].fillna(z['Age of car'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\457627854.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z['Age of car'].fillna(z['Age of car'].median(),inplace=True)

# %%
z['engine_displacement'].fillna(z['engine_displacement'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\2144280519.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z['engine_displacement'].fillna(z['engine_displacement'].median(),inplace=True)

# %%
z['engine_power'].fillna(z['engine_power'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1688953780.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z['engine_power'].fillna(z['engine_power'].median(),inplace=True)

# %%
z['door_count'].fillna(z['door_count'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\3336928551.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z['door_count'].fillna(z['door_count'].median(),inplace=True)

# %%
z['seat_count'].fillna(z['seat_count'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1569745793.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z['seat_count'].fillna(z['seat_count'].median(),inplace=True)

# %%
df_noutliers=df_cat[['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
       'Id','Vroom Audit Rating','Price']]

# %%
df_noutliers['Price'].isna().sum()
# Out:
# np.int64(0)

# %%
df_cat.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
#        'Id', 'Distance ', 'manufacture_year', 'Age of car',
#        'engine_displacement', 'engine_power', 'Vroom Audit Rating',
#        'door_count', 'seat_count', 'Price'],
#       dtype='object')

# %%
df=pd.concat([df_noutliers,df_outliers],axis=1)

# %%
df[['Price']].isna().sum()
# Out:
# Price    0
# dtype: int64

# %%
df.boxplot()
plt.show()

# %%
df.isna().sum()
# Out:
# Maker                  0
# model                  0
# Location               0
# Owner Type             0
# transmission           0
# fuel_type              0
# Id                     0
# Vroom Audit Rating     0
# Price                  0
# Distance               0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# door_count             0
# seat_count             0
# dtype: int64

# %%
df[['Price']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   53515 non-null  int64
# dtypes: int64(1)
# memory usage: 418.2 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
df_bnorm=df_cat[['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
       'Id', 'Distance ', 'manufacture_year', 'Age of car',
       'engine_displacement', 'engine_power', 'Vroom Audit Rating',
       'door_count', 'seat_count']]

# %%
df_norm=pd.DataFrame(mms.fit_transform(df_bnorm),columns=df_bnorm.columns)

# %%
df_norm
# Out:
#           Maker     model  Location  Owner Type  transmission  fuel_type  \
# 0      0.857143  0.363636       0.0    0.666667           1.0        1.0
# 1      0.285714  0.409091       0.0    1.000000           1.0        1.0
# 2      0.142857  0.818182       0.5    1.000000           0.0        0.0
# 3      0.714286  0.272727       0.9    1.000000           1.0        1.0
# 4      0.142857  0.909091       0.6    0.333333           0.0        0.0
# ...         ...       ...       ...         ...           ...        ...
# 53510  0.857143  0.363636       0.4    0.333333           1.0        0.0
# 53511  0.857143  0.363636       0.1    0.333333           1.0        0.0
# 53512  0.142857  0.818182       1.0    1.000000           0.0        0.0
# 53513  1.000000  0.045455       0.6    1.000000           1.0        0.0
# 53514  0.142857  0.909091       0.7    0.000000           0.0        0.0
#
#              Id  Distance   manufacture_year  Age of car  engine_displacement  \
# ...

# %%
df=pd.concat([df_norm,df_cat[['Price']]],axis=1)

# %%
df
# Out:
#           Maker     model  Location  Owner Type  transmission  fuel_type  \
# 0      0.857143  0.363636       0.0    0.666667           1.0        1.0
# 1      0.285714  0.409091       0.0    1.000000           1.0        1.0
# 2      0.142857  0.818182       0.5    1.000000           0.0        0.0
# 3      0.714286  0.272727       0.9    1.000000           1.0        1.0
# 4      0.142857  0.909091       0.6    0.333333           0.0        0.0
# ...         ...       ...       ...         ...           ...        ...
# 53510  0.857143  0.363636       0.4    0.333333           1.0        0.0
# 53511  0.857143  0.363636       0.1    0.333333           1.0        0.0
# 53512  0.142857  0.818182       1.0    1.000000           0.0        0.0
# 53513  1.000000  0.045455       0.6    1.000000           1.0        0.0
# 53514  0.142857  0.909091       0.7    0.000000           0.0        0.0
#
#              Id  Distance   manufacture_year  Age of car  engine_displacement  \
# ...

# %%
df[['Price']].isna().sum()
# Out:
# Price    0
# dtype: int64

# %%
df.corr()
# Out:
#                         Maker     model  Location  Owner Type  transmission  \
# Maker                1.000000 -0.219570  0.004939   -0.002007      0.379159
# model               -0.219570  1.000000 -0.002771    0.005100     -0.219969
# Location             0.004939 -0.002771  1.000000    0.006910      0.010126
# Owner Type          -0.002007  0.005100  0.006910    1.000000     -0.000978
# transmission         0.379159 -0.219969  0.010126   -0.000978      1.000000
# fuel_type            0.246158 -0.192607  0.003823   -0.006580      0.194639
# Id                   0.001518 -0.001851  0.006328    0.003215     -0.005550
# Distance             0.040944 -0.008275  0.004632   -0.004258      0.017691
# manufacture_year    -0.069465  0.064531 -0.004839   -0.004829     -0.127930
# Age of car           0.069465 -0.064531  0.004839    0.004829      0.127930
# engine_displacement -0.195926  0.092360  0.004376    0.002344     -0.207715
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
X_train=df[['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
       'Id', 'Distance ', 'manufacture_year', 'Age of car',
       'engine_displacement', 'engine_power', 'Vroom Audit Rating',
       'door_count','seat_count']]
y_train=df[['Price']]

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   53515 non-null  int64
# dtypes: int64(1)
# memory usage: 418.2 KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maker                53515 non-null  float64
#  1   model                53515 non-null  float64
#  2   Location             53515 non-null  float64
#  3   Owner Type           53515 non-null  float64
#  4   transmission         53515 non-null  float64
#  5   fuel_type            53515 non-null  float64
#  6   Id                   53515 non-null  float64
#  7   Distance             53515 non-null  float64
#  8   manufacture_year     53515 non-null  float64
#  9   Age of car           53515 non-null  float64
#  10  engine_displacement  53515 non-null  float64
#  11  engine_power         53515 non-null  float64
#  12  Vroom Audit Rating   53515 non-null  float64
#  13  door_count           53515 non-null  float64
#  14  seat_count           53515 non-null  float64
# ...

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-5.76137021e+05,  8.66325187e+04, -1.44445611e+03,
#         -3.98088081e+03, -2.61161150e+05, -1.21938930e+05,
#          2.15930540e+03, -1.52308460e+06,  3.95418450e+19,
#          3.95418450e+19,  1.13762272e+05,  5.75563809e+06,
#          5.73134892e+03, -3.68774839e+05,  8.32732428e+05]])

# %%
model.intercept_
# Out:
# array([-3.9541845e+19])

# %%
y_predicted=pd.DataFrame(model.predict(X_train),columns=['y_predicted'])

# %%
y_predicted
# Out:
#        y_predicted
# 0       -2523136.0
# 1         901120.0
# 2        1990656.0
# 3        1130496.0
# 4        2359296.0
# ...            ...
# 53510    1097728.0
# 53511     557056.0
# 53512    2056192.0
# 53513     614400.0
# 53514    1835008.0
#
# [53515 rows x 1 columns]

# %%
y_train.isna().sum()
# Out:
# Price    0
# dtype: int64

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   53515 non-null  int64
# dtypes: int64(1)
# memory usage: 418.2 KB

# %%
y=df[['Price']]
df1=pd.concat([y_train,y_predicted],axis=1)
df1
# Out:
#          Price  y_predicted
# 0       543764   -2523136.0
# 1       401819     901120.0
# 2      2392855    1990656.0
# 3       958606    1130496.0
# 4      3085561    2359296.0
# ...        ...          ...
# 53510  1342996    1097728.0
# 53511   510732     557056.0
# 53512  2008123    2056192.0
# 53513   874352     614400.0
# 53514  1576610    1835008.0
#
# [53515 rows x 2 columns]

# %%
df1.isna().sum()
# Out:
# Price          0
# y_predicted    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Price        53515 non-null  int64
#  1   y_predicted  53515 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 836.3 KB

# %%
df1['Residuals']=df1['Price']-df1['y_predicted']

# %%
df1
# Out:
#          Price  y_predicted  Residuals
# 0       543764   -2523136.0  3066900.0
# 1       401819     901120.0  -499301.0
# 2      2392855    1990656.0   402199.0
# 3       958606    1130496.0  -171890.0
# 4      3085561    2359296.0   726265.0
# ...        ...          ...        ...
# 53510  1342996    1097728.0   245268.0
# 53511   510732     557056.0   -46324.0
# 53512  2008123    2056192.0   -48069.0
# 53513   874352     614400.0   259952.0
# 53514  1576610    1835008.0  -258398.0
#
# [53515 rows x 3 columns]

# %%
model.score(X_train,y_train)
# Out:
# 0.6985238030374352

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(df1['Price'],df1['y_predicted'])
# Out:
# np.float64(214827995166.03564)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(df1['Price'],df1['y_predicted'])
# Out:
# np.float64(290692.50150425115)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
df_norm=pd.DataFrame(mms.fit_transform(df_cat),columns=df_cat.columns)

# %%
df_norm
# Out:
#           Maker     model  Location  Owner Type  transmission  fuel_type  \
# 0      0.857143  0.363636       0.0    0.666667           1.0        1.0
# 1      0.285714  0.409091       0.0    1.000000           1.0        1.0
# 2      0.142857  0.818182       0.5    1.000000           0.0        0.0
# 3      0.714286  0.272727       0.9    1.000000           1.0        1.0
# 4      0.142857  0.909091       0.6    0.333333           0.0        0.0
# ...         ...       ...       ...         ...           ...        ...
# 53510  0.857143  0.363636       0.4    0.333333           1.0        0.0
# 53511  0.857143  0.363636       0.1    0.333333           1.0        0.0
# 53512  0.142857  0.818182       1.0    1.000000           0.0        0.0
# 53513  1.000000  0.045455       0.6    1.000000           1.0        0.0
# 53514  0.142857  0.909091       0.7    0.000000           0.0        0.0
#
#              Id  Distance   manufacture_year  Age of car  engine_displacement  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df_stand=pd.DataFrame(ss.fit_transform(df_cat),columns=df_cat.columns)

# %%
df_stand
# Out:
#           Maker     model  Location  Owner Type  transmission  fuel_type  \
# 0      0.670441 -0.525379 -1.586828    0.447065      0.675888   1.030417
# 1     -0.895167 -0.363222 -1.586828    1.340911      0.675888   1.030417
# 2     -1.286569  1.096195 -0.003090    1.340911     -1.479535  -0.970481
# 3      0.279039 -0.849694  1.263901    1.340911      0.675888   1.030417
# 4     -1.286569  1.420509  0.313658   -0.446781     -1.479535  -0.970481
# ...         ...       ...       ...         ...           ...        ...
# 53510  0.670441 -0.525379 -0.319837   -0.446781      0.675888  -0.970481
# 53511  0.670441 -0.525379 -1.270080   -0.446781      0.675888  -0.970481
# 53512 -1.286569  1.096195  1.580648    1.340911     -1.479535  -0.970481
# 53513  1.061843 -1.660480  0.313658    1.340911      0.675888  -0.970481
# 53514 -1.286569  1.420509  0.630406   -1.340627     -1.479535  -0.970481
#
#              Id  Distance   manufacture_year  Age of car  engine_displacement  \
# ...

# %%
df_stand.std()
# Out:
# Maker                  1.000009
# model                  1.000009
# Location               1.000009
# Owner Type             1.000009
# transmission           1.000009
# fuel_type              1.000009
# Id                     1.000009
# Distance               1.000009
# manufacture_year       1.000009
# Age of car             1.000009
# engine_displacement    1.000009
# engine_power           1.000009
# Vroom Audit Rating     1.000009
# door_count             1.000009
# seat_count             1.000009
# Price                  1.000009
# dtype: float64

# %%
df_stand.mean()
# Out:
# Maker                  2.217334e-17
# model                  3.213143e-17
# Location              -1.885398e-17
# Owner Type            -4.491097e-17
# transmission          -1.100701e-16
# fuel_type             -1.228164e-16
# Id                    -3.399027e-17
# Distance               2.170863e-17
# manufacture_year      -9.174652e-15
# Age of car            -2.204057e-17
# engine_displacement   -4.116009e-17
# engine_power          -7.926638e-17
# Vroom Audit Rating     3.021948e-16
# door_count            -9.294215e-19
# seat_count             6.673246e-16
# Price                  5.410561e-17
# dtype: float64

# %%
mean_value=np.mean(df_stand)
print(np.isclose(mean_value,0))
# Out:
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Test_Data_Set (5).csv')
df
# Out:
#          Id    Maker    model    Location  Distance       Owner Type  \
# 0     11001    skoda  octavia      Mumbai   150000.0           First
# 1     11002    skoda    rapid  Coimbatore    29376.0           Third
# 2     11003    skoda  octavia  Coimbatore    30563.0          Second
# 3     11004     audi       q3       Delhi     8650.0  Fourth & Above
# 4     11005     audi       tt     Chennai     6400.0           Third
# ...     ...      ...      ...         ...        ...             ...
# 5610  16611    skoda  octavia      Mumbai   149976.0           First
# 5611  16612    skoda   superb   Ahmedabad   332000.0           First
# 5612  16613    skoda  octavia   Bangalore   230800.0          Second
# 5613  16614   nissan  qashqai      Jaipur    63480.0           Third
# 5614  16615  hyundai      i30      Jaipur    75000.0          Second
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
df.isna().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                128
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power            168
# body_type              5193
# Vroom Audit Rating        0
# transmission              0
# door_count              806
# seat_count              891
# fuel_type                 0
# dtype: int64

# %%
df.count()
# Out:
# Id                     5615
# Maker                  5615
# model                  5615
# Location               5615
# Distance               5487
# Owner Type             5615
# manufacture_year       5615
# Age of car             5615
# engine_displacement    5615
# engine_power           5447
# body_type               422
# Vroom Audit Rating     5615
# transmission           5615
# door_count             4809
# seat_count             4724
# fuel_type              5615
# dtype: int64

# %%
del df['body_type']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5615 entries, 0 to 5614
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5615 non-null   int64
#  1   Maker                5615 non-null   object
#  2   model                5615 non-null   object
#  3   Location             5615 non-null   object
#  4   Distance             5487 non-null   float64
#  5   Owner Type           5615 non-null   object
#  6   manufacture_year     5615 non-null   int64
#  7   Age of car           5615 non-null   int64
#  8   engine_displacement  5615 non-null   int64
#  9   engine_power         5447 non-null   float64
#  10  Vroom Audit Rating   5615 non-null   int64
#  11  transmission         5615 non-null   object
#  12  door_count           4809 non-null   float64
#  13  seat_count           4724 non-null   float64
#  14  fuel_type            5615 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type'],
#       dtype='object')

# %%
df['Distance '].fillna(df['Distance '].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\2970458654.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Distance '].fillna(df['Distance '].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# Id                       0
# Maker                    0
# model                    0
# Location                 0
# Distance                 0
# Owner Type               0
# manufacture_year         0
# Age of car               0
# engine_displacement      0
# engine_power           168
# Vroom Audit Rating       0
# transmission             0
# door_count             806
# seat_count             891
# fuel_type                0
# dtype: int64

# %%
df['engine_power'].fillna(df['engine_power'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\3278638123.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['engine_power'].fillna(df['engine_power'].mode()[0],inplace=True)

# %%
df['door_count'].fillna(df['door_count'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\269680246.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['door_count'].fillna(df['door_count'].mode()[0],inplace=True)

# %%
df['seat_count'].fillna(df['seat_count'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1285228065.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['seat_count'].fillna(df['seat_count'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5615 entries, 0 to 5614
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5615 non-null   int64
#  1   Maker                5615 non-null   object
#  2   model                5615 non-null   object
#  3   Location             5615 non-null   object
#  4   Distance             5615 non-null   float64
#  5   Owner Type           5615 non-null   object
#  6   manufacture_year     5615 non-null   int64
#  7   Age of car           5615 non-null   int64
#  8   engine_displacement  5615 non-null   int64
#  9   engine_power         5615 non-null   float64
#  10  Vroom Audit Rating   5615 non-null   int64
#  11  transmission         5615 non-null   object
#  12  door_count           5615 non-null   float64
#  13  seat_count           5615 non-null   float64
#  14  fuel_type            5615 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cat=df.select_dtypes(include='object')

# %%
df_cat
# Out:
#         Maker    model    Location      Owner Type transmission fuel_type
# 0       skoda  octavia      Mumbai           First          man    petrol
# 1       skoda    rapid  Coimbatore           Third          man    diesel
# 2       skoda  octavia  Coimbatore          Second          man    diesel
# 3        audi       q3       Delhi  Fourth & Above         auto    diesel
# 4        audi       tt     Chennai           Third         auto    petrol
# ...       ...      ...         ...             ...          ...       ...
# 5610    skoda  octavia      Mumbai           First          man    diesel
# 5611    skoda   superb   Ahmedabad           First          man    diesel
# 5612    skoda  octavia   Bangalore          Second          man    diesel
# 5613   nissan  qashqai      Jaipur           Third          man    petrol
# 5614  hyundai      i30      Jaipur          Second          man    petrol
#
# [5615 rows x 6 columns]

# %%
df_num=df.select_dtypes(exclude='object').astype('int')
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5615 entries, 0 to 5614
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5615 non-null   int64
#  1   Distance             5615 non-null   int64
#  2   manufacture_year     5615 non-null   int64
#  3   Age of car           5615 non-null   int64
#  4   engine_displacement  5615 non-null   int64
#  5   engine_power         5615 non-null   int64
#  6   Vroom Audit Rating   5615 non-null   int64
#  7   door_count           5615 non-null   int64
#  8   seat_count           5615 non-null   int64
# dtypes: int64(9)
# memory usage: 394.9 KB

# %%
df_cat
# Out:
#         Maker    model    Location      Owner Type transmission fuel_type
# 0       skoda  octavia      Mumbai           First          man    petrol
# 1       skoda    rapid  Coimbatore           Third          man    diesel
# 2       skoda  octavia  Coimbatore          Second          man    diesel
# 3        audi       q3       Delhi  Fourth & Above         auto    diesel
# 4        audi       tt     Chennai           Third         auto    petrol
# ...       ...      ...         ...             ...          ...       ...
# 5610    skoda  octavia      Mumbai           First          man    diesel
# 5611    skoda   superb   Ahmedabad           First          man    diesel
# 5612    skoda  octavia   Bangalore          Second          man    diesel
# 5613   nissan  qashqai      Jaipur           Third          man    petrol
# 5614  hyundai      i30      Jaipur          Second          man    petrol
#
# [5615 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df_cat.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Owner Type', 'transmission',
#        'fuel_type'],
#       dtype='object')

# %%
df_cat['Maker']=le.fit_transform(df_cat['Maker'])

# %%
df_cat
# Out:
#       Maker    model    Location      Owner Type transmission fuel_type
# 0         6  octavia      Mumbai           First          man    petrol
# 1         6    rapid  Coimbatore           Third          man    diesel
# 2         6  octavia  Coimbatore          Second          man    diesel
# 3         0       q3       Delhi  Fourth & Above         auto    diesel
# 4         0       tt     Chennai           Third         auto    petrol
# ...     ...      ...         ...             ...          ...       ...
# 5610      6  octavia      Mumbai           First          man    diesel
# 5611      6   superb   Ahmedabad           First          man    diesel
# 5612      6  octavia   Bangalore          Second          man    diesel
# 5613      5  qashqai      Jaipur           Third          man    petrol
# 5614      3      i30      Jaipur          Second          man    petrol
#
# [5615 rows x 6 columns]

# %%
df_cat['model']=le.fit_transform(df_cat['model'])

# %%
df_cat['Location']=le.fit_transform(df_cat['Location'])

# %%
df_cat['Owner Type']=le.fit_transform(df_cat['Owner Type'])

# %%
df_cat['transmission']=le.fit_transform(df_cat['transmission'])

# %%
df_cat['fuel_type']=le.fit_transform(df_cat['fuel_type'])

# %%
df_cat
# Out:
#       Maker  model  Location  Owner Type  transmission  fuel_type
# 0         6      8         9           0             1          1
# 1         6     14         3           3             1          0
# 2         6      8         3           2             1          0
# 3         0     10         4           1             0          0
# 4         0     17         2           3             0          1
# ...     ...    ...       ...         ...           ...        ...
# 5610      6      8         9           0             1          0
# 5611      6     16         0           0             1          0
# 5612      6      8         1           2             1          0
# 5613      5     13         6           3             1          1
# 5614      3      5         6           2             1          1
#
# [5615 rows x 6 columns]

# %%
df=pd.concat([df_cat,df_num],axis=1)
df
# Out:
#       Maker  model  Location  Owner Type  transmission  fuel_type     Id  \
# 0         6      8         9           0             1          1  11001
# 1         6     14         3           3             1          0  11002
# 2         6      8         3           2             1          0  11003
# 3         0     10         4           1             0          0  11004
# 4         0     17         2           3             0          1  11005
# ...     ...    ...       ...         ...           ...        ...    ...
# 5610      6      8         9           0             1          0  16611
# 5611      6     16         0           0             1          0  16612
# 5612      6      8         1           2             1          0  16613
# 5613      5     13         6           3             1          1  16614
# 5614      3      5         6           2             1          1  16615
#
#       Distance   manufacture_year  Age of car  engine_displacement  \
# ...

# %%
df.boxplot(figsize=(12,8))
plt.show()

# %%
df.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
#        'Id', 'Distance ', 'manufacture_year', 'Age of car',
#        'engine_displacement', 'engine_power', 'Vroom Audit Rating',
#        'door_count', 'seat_count'],
#       dtype='object')

# %%
df_outliers=df[['Distance ', 'manufacture_year', 'Age of car','engine_displacement', 'engine_power','door_count', 'seat_count']]

# %%
df_outliers=df[['Distance ', 'manufacture_year', 'Age of car','engine_displacement', 'engine_power','door_count', 'seat_count']]
df_outliers
# Out:
#       Distance   manufacture_year  Age of car  engine_displacement  \
# 0        150000              2007          12                 1595
# 1         29376              2014           5                 1598
# 2         30563              2014           5                 1968
# 3          8650              2015           4                 1968
# 4          6400              2015           4                 1984
# ...         ...               ...         ...                  ...
# 5610     149976              2011           8                 1968
# 5611     332000              2005          14                 1896
# 5612     230800              2005          14                 1896
# 5613      63480              2011           8                 1997
# 5614      75000              2011           8                 1396
#
#       engine_power  door_count  seat_count
# 0               75           4           5
# 1               77           4           5
# ...

# %%
z=(df_outliers-df_outliers.mean())/df_outliers.std()

# %%
z_reduced=z[(z>-2)&(z<2)]

# %%
z_reduced.boxplot()
plt.show()

# %%
z_reduced.isna().sum()
# Out:
# Distance                20
# manufacture_year       307
# Age of car             307
# engine_displacement     55
# engine_power           235
# door_count             432
# seat_count             169
# dtype: int64

# %%
z_reduced['Distance '].fillna(z_reduced['Distance '].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\3985156834.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z_reduced['Distance '].fillna(z_reduced['Distance '].median(),inplace=True)

# %%
z_reduced['manufacture_year'].fillna(z_reduced['manufacture_year'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\4042992374.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z_reduced['manufacture_year'].fillna(z_reduced['manufacture_year'].median(),inplace=True)

# %%
z_reduced['Age of car'].fillna(z_reduced['Age of car'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1398960989.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z_reduced['Age of car'].fillna(z_reduced['Age of car'].median(),inplace=True)

# %%
z_reduced['engine_displacement'].fillna(z_reduced['engine_displacement'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1678962937.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z_reduced['engine_displacement'].fillna(z_reduced['engine_displacement'].median(),inplace=True)

# %%
z_reduced['engine_power'].fillna(z_reduced['engine_power'].median(),inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\4098886100.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z_reduced['engine_power'].fillna(z_reduced['engine_power'].median(),inplace=True)

# %%
z_reduced['door_count'].fillna(z_reduced['door_count'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\1909421535.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z_reduced['door_count'].fillna(z_reduced['door_count'].mode()[0],inplace=True)

# %%
z_reduced['seat_count'].fillna(z_reduced['seat_count'].mode()[0],inplace=True)
# Out:
# C:\Users\ajayk\AppData\Local\Temp\ipykernel_17320\3620540090.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   z_reduced['seat_count'].fillna(z_reduced['seat_count'].mode()[0],inplace=True)

# %%
z_reduced.isna().sum()
# Out:
# Distance               0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# door_count             0
# seat_count             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
#        'Id', 'Distance ', 'manufacture_year', 'Age of car',
#        'engine_displacement', 'engine_power', 'Vroom Audit Rating',
#        'door_count', 'seat_count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5615 entries, 0 to 5614
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Maker                5615 non-null   int64
#  1   model                5615 non-null   int64
#  2   Location             5615 non-null   int64
#  3   Owner Type           5615 non-null   int64
#  4   transmission         5615 non-null   int64
#  5   fuel_type            5615 non-null   int64
#  6   Id                   5615 non-null   int64
#  7   Distance             5615 non-null   int64
#  8   manufacture_year     5615 non-null   int64
#  9   Age of car           5615 non-null   int64
#  10  engine_displacement  5615 non-null   int64
#  11  engine_power         5615 non-null   int64
#  12  Vroom Audit Rating   5615 non-null   int64
#  13  door_count           5615 non-null   int64
#  14  seat_count           5615 non-null   int64
# dtypes: int64(15)
# ...

# %%
df_nout=df[['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
       'Id','Vroom Audit Rating']]

# %%
df_nout
# Out:
#       Maker  model  Location  Owner Type  transmission  fuel_type     Id  \
# 0         6      8         9           0             1          1  11001
# 1         6     14         3           3             1          0  11002
# 2         6      8         3           2             1          0  11003
# 3         0     10         4           1             0          0  11004
# 4         0     17         2           3             0          1  11005
# ...     ...    ...       ...         ...           ...        ...    ...
# 5610      6      8         9           0             1          0  16611
# 5611      6     16         0           0             1          0  16612
# 5612      6      8         1           2             1          0  16613
# 5613      5     13         6           3             1          1  16614
# 5614      3      5         6           2             1          1  16615
#
#       Vroom Audit Rating
# 0                      5
# 1                      4
# ...

# %%
df=pd.concat([df_nout,df_outliers],axis=1)

# %%
df
# Out:
#       Maker  model  Location  Owner Type  transmission  fuel_type     Id  \
# 0         6      8         9           0             1          1  11001
# 1         6     14         3           3             1          0  11002
# 2         6      8         3           2             1          0  11003
# 3         0     10         4           1             0          0  11004
# 4         0     17         2           3             0          1  11005
# ...     ...    ...       ...         ...           ...        ...    ...
# 5610      6      8         9           0             1          0  16611
# 5611      6     16         0           0             1          0  16612
# 5612      6      8         1           2             1          0  16613
# 5613      5     13         6           3             1          1  16614
# 5614      3      5         6           2             1          1  16615
#
#       Vroom Audit Rating  Distance   manufacture_year  Age of car  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df_stand=pd.DataFrame(ss.fit_transform(df),columns=df.columns)

# %%
df_stand
# Out:
#          Maker     model  Location  Owner Type  transmission  fuel_type  \
# 0     0.657061 -0.509422  1.278079   -1.302263      0.665081   1.027264
# 1     0.657061  0.469164 -0.621867    1.345488      0.665081  -0.973460
# 2     0.657061 -0.509422 -0.621867    0.462905      0.665081  -0.973460
# 3    -1.713510 -0.183227 -0.305209   -0.419679     -1.503577  -0.973460
# 4    -1.713510  0.958457 -0.938525    1.345488     -1.503577   1.027264
# ...        ...       ...       ...         ...           ...        ...
# 5610  0.657061 -0.509422  1.278079   -1.302263      0.665081  -0.973460
# 5611  0.657061  0.795359 -1.571840   -1.302263      0.665081  -0.973460
# 5612  0.657061 -0.509422 -1.255182    0.462905      0.665081  -0.973460
# 5613  0.261966  0.306066  0.328106    1.345488      0.665081   1.027264
# 5614 -0.528224 -0.998715  0.328106    0.462905      0.665081   1.027264
#
#             Id  Vroom Audit Rating  Distance   manufacture_year  Age of car  \
# ...

# %%
df_stand.std()
# Out:
# Maker                  1.000089
# model                  1.000089
# Location               1.000089
# Owner Type             1.000089
# transmission           1.000089
# fuel_type              1.000089
# Id                     1.000089
# Vroom Audit Rating     1.000089
# Distance               1.000089
# manufacture_year       1.000089
# Age of car             1.000089
# engine_displacement    1.000089
# engine_power           1.000089
# door_count             1.000089
# seat_count             1.000089
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
df_stand.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
#        'Id', 'Vroom Audit Rating', 'Distance ', 'manufacture_year',
#        'Age of car', 'engine_displacement', 'engine_power', 'door_count',
#        'seat_count'],
#       dtype='object')

# %%
X_test=df[['Maker', 'model', 'Location', 'Owner Type', 'transmission', 'fuel_type',
       'Id', 'Distance ', 'manufacture_year', 'Age of car',
       'engine_displacement', 'engine_power', 'Vroom Audit Rating',
       'door_count','seat_count']]

# %%
X_test.count()
# Out:
# Maker                  5615
# model                  5615
# Location               5615
# Owner Type             5615
# transmission           5615
# fuel_type              5615
# Id                     5615
# Distance               5615
# manufacture_year       5615
# Age of car             5615
# engine_displacement    5615
# engine_power           5615
# Vroom Audit Rating     5615
# door_count             5615
# seat_count             5615
# dtype: int64

# %%
y_train.count()
# Out:
# Price    53515
# dtype: int64

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_predicted=pd.DataFrame(model.predict(X_test),columns=['y_test_predicted'])

# %%
y_test_predicted
# Out:
#       y_test_predicted
# 0         7.979544e+22
# 1         7.979544e+22
# 2         7.979544e+22
# 3         7.979544e+22
# 4         7.979544e+22
# ...                ...
# 5610      7.979544e+22
# 5611      7.979544e+22
# 5612      7.979544e+22
# 5613      7.979544e+22
# 5614      7.979544e+22
#
# [5615 rows x 1 columns]

# %%
test_predicted=pd.concat([X_test['Id'],y_test_predicted],axis=1)

# %%
test_predicted
# Out:
#          Id  y_test_predicted
# 0     11001      7.979544e+22
# 1     11002      7.979544e+22
# 2     11003      7.979544e+22
# 3     11004      7.979544e+22
# 4     11005      7.979544e+22
# ...     ...               ...
# 5610  16611      7.979544e+22
# 5611  16612      7.979544e+22
# 5612  16613      7.979544e+22
# 5613  16614      7.979544e+22
# 5614  16615      7.979544e+22
#
# [5615 rows x 2 columns]

# %%
test_predicted.to_csv('Predicted Price.csv')
